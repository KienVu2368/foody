# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.learner import *

import torchtext
from torchtext import vocab, data
from torchtext.datasets import language_modeling

from fastai.rnn_reg import *
from fastai.rnn_train import *
from fastai.nlp import *
#from fastai.text import *
from fastai.lm_rnn import *

import dill as pickle
# Out:
# /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   return f(*args, **kwds)

# %% [markdown]
# ## Language modeling

# %% [markdown]
# ### Data

# %%
reviews_label = pd.read_pickle('/media/zero/Data/Dropbox/metadata/foody review/foody review.pkl')

# %%
reviews = reviews_label[['review_content']]

# %%
PATH = '/home/zero/fastai/courses/dl1/data/foody/'

# %%
bs=64; bptt=10

# %%
TEXT = data.Field(lower=True, tokenize=spacy_tok)

# %%
??LanguageModelData

# %%
md = LanguageModelData.from_dataframes(PATH, TEXT, col = 'review_content', 
                                       train_df = reviews[:1000] , val_df=reviews[1000:1500], test_df=reviews[1000:1500],
                                       bs=bs, bptt=bptt, min_freq=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-1ef584867795> in <module>()
# ----> 1 md = LanguageModelData.from_dataframes(PATH, TEXT, col = 'review_content',
#       2                                        train_df = reviews[:1000] , val_df=reviews[1000:1500], test_df=reviews[1000:1500],
#       3                                        bs=bs, bptt=bptt, min_freq=10)
#
# AttributeError: type object 'LanguageModelData' has no attribute 'from_dataframes'

# %% [markdown]
# After building our `ModelData` object, it automatically fills the `TEXT` object with a very important attribute: `TEXT.vocab`. This is a *vocabulary*, which stores which words (or *tokens*) have been seen in the text, and how each word will be mapped to a unique integer id. We'll need to use this information again later, so we save it.
#
# *(Technical note: python's standard `Pickle` library can't handle this correctly, so at the top of this notebook we used the `dill` library instead and imported it as `pickle`)*.

# %%
pickle.dump(TEXT, open(f'{PATH}models/TEXT.pkl','wb'))

# %% [markdown]
# Here are the: # batches; # unique tokens in the vocab; # tokens in the training set; # sentences

# %%
len(md.trn_dl), md.nt, len(md.trn_ds), len(md.trn_ds[0].text)
# Out:
# (178, 1141, 1, 114596)

# %% [markdown]
# This is the start of the mapping from integer IDs to unique tokens.

# %%
# 'itos': 'int-to-string'
TEXT.vocab.itos[:12]
# Out:
# ['<unk>',
#  '<pad>',
#  ',',
#  '.',
#  'mình',
#  'ăn',
#  '\n',
#  'có',
#  'quán',
#  'là',
#  'không',
#  'thì']

# %%
# 'stoi': 'string to int'
TEXT.vocab.stoi['ngon']
# Out:
# 14

# %% [markdown]
# Note that in a `LanguageModelData` object there is only one item in each dataset: all the words of the text joined together.

# %%
md.trn_ds[0].text[:12]
# Out:
# ['quán',
#  'steak',
#  'hiếm',
#  'hoi',
#  'mà',
#  'mình',
#  'cực',
#  'kì',
#  'ưng',
#  'ý',
#  'từ',
#  'lâu']

# %% [markdown]
# torchtext will handle turning this words into integer IDs for us automatically.

# %%
TEXT.numericalize([md.trn_ds[0].text[:12]])
# Out:
# Variable containing:
#     8
#     0
#     0
#     0
#    20
#     4
#   118
#   402
#   525
#   187
#   125
#   151
# [torch.LongTensor of size 12x1]

# %% [markdown]
# Our `LanguageModelData` object will create batches with 64 columns (that's our batch size), and varying sequence lengths of around 80 tokens (that's our `bptt` parameter - *backprop through time*).
#
# Each batch also contains the exact same data as labels, but one word later in the text - since we're trying to always predict the next word. The labels are flattened into a 1d array.

# %%
# %debug next(iter(md.trn_dl))
# Out:
# NOTE: Enter 'c' at the ipdb>  prompt to continue execution.
# > <string>(1)<module>()
#
# ipdb> s
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/nlp.py(128)__iter__()
#     126         self.n = len(self.data)
#     127
# --> 128     def __iter__(self):
#     129         self.i,self.iter = 0,0
#     130         return self
#
# ipdb> ll
# --> 128     def __iter__(self):
#     129         self.i,self.iter = 0,0
#     130         return self
#     131
#
# ipdb> s
# > /home/zero/fastai/courses/dl1/fastai/nlp.py(129)__iter__()
#     127
#     128     def __iter__(self):
# --> 129         self.i,self.iter = 0,0
#     130         return self
#     131
#
# ipdb>
# > /home/zero/fastai/courses/dl1/fastai/nlp.py(130)__iter__()
#     128     def __iter__(self):
#     129         self.i,self.iter = 0,0
# --> 130         return self
#     131
#     132     def __len__(self): return self.n // self.bptt - 1
#
# ipdb> s
# --Return--
# <fastai.nlp.L...x7f7254d24898>
# > /home/zero/fastai/courses/dl1/fastai/nlp.py(130)__iter__()
#     128     def __iter__(self):
#     129         self.i,self.iter = 0,0
# --> 130         return self
#     131
#     132     def __len__(self): return self.n // self.bptt - 1
#
# ipdb> s
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/nlp.py(134)__next__()
#     132     def __len__(self): return self.n // self.bptt - 1
#     133
# --> 134     def __next__(self):
#     135         if self.i >= self.n-1 or self.iter>=len(self): raise StopIteration
#     136         bptt = self.bptt if np.random.random() < 0.95 else self.bptt / 2.
#
# ipdb> ll
# --> 134     def __next__(self):
#     135         if self.i >= self.n-1 or self.iter>=len(self): raise StopIteration
#     136         bptt = self.bptt if np.random.random() < 0.95 else self.bptt / 2.
#     137         seq_len = max(5, int(np.random.normal(bptt, 5)))
#     138         res = self.get_batch(self.i, seq_len)
#     139         self.i += seq_len
#     140         self.iter += 1
#     141         return res
#     142
#
# ipdb> c

# %% [markdown]
# ### Train

# %% [markdown]
# We have a number of parameters to set - we'll learn more about these later, but you should find these values suitable for many problems.

# %%
em_sz = 20  # size of each embedding vector
nh = 50     # number of hidden activations per layer
nl = 2       # number of layers

# %% [markdown]
# Researchers have found that large amounts of *momentum* (which we'll learn about later) don't work well with these kinds of *RNN* models, so we create a version of the *Adam* optimizer with less momentum than it's default of `0.9`.

# %%
opt_fn = partial(optim.Adam, betas=(0.7, 0.99))

# %% [markdown]
# fastai uses a variant of the state of the art [AWD LSTM Language Model](https://arxiv.org/abs/1708.02182) developed by Stephen Merity. A key feature of this model is that it provides excellent regularization through [Dropout](https://en.wikipedia.org/wiki/Convolutional_neural_network#Dropout). There is no simple way known (yet!) to find the best values of the dropout parameters below - you just have to experiment...
#
# However, the other parameters (`alpha`, `beta`, and `clip`) shouldn't generally need tuning.

# %%
# %debug md.get_model(opt_fn, em_sz, nh, nl, dropouti=0.05, dropout=0.05, wdrop=0.1, dropoute=0.02, dropouth=0.05)
# Out:
# NOTE: Enter 'c' at the ipdb>  prompt to continue execution.
# > <string>(1)<module>()
#
# ipdb> s
# > <string>(2)<module>()
#
# ipdb> s
# > <string>(3)<module>()
#
# ipdb> s
# > <string>(4)<module>()
#
# ipdb> s
# > <string>(5)<module>()
#
# ipdb> s
# > <string>(6)<module>()
#
# ipdb> ll
# *** could not get source code
# ipdb> s
# > <string>(7)<module>()
#
# ipdb> s
# > <string>(8)<module>()
#
# ipdb> s
# > <string>(9)<module>()
#
# ipdb> s
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/nlp.py(256)get_model()
#     254                                                   for ds in (self.trn_ds, self.val_ds, self.test_ds) ]
#     255
# --> 256     def get_model(self, opt_fn, emb_sz, n_hid, n_layers, **kwargs):
#     257         """ Method returns a RNN_Learner object, that wraps an instance of the RNN_Encoder module.
#     258
#
# ipdb> ll
# --> 256     def get_model(self, opt_fn, emb_sz, n_hid, n_layers, **kwargs):
#     257         """ Method returns a RNN_Learner object, that wraps an instance of the RNN_Encoder module.
#     258
#     259         Args:
#     260             opt_fn (Optimizer): the torch optimizer function to use
#     261             emb_sz (int): embedding size
#     262             n_hid (int): number of hidden inputs
#     263             n_layers (int): number of hidden layers
#     264             kwargs: other arguments
#     265
#     266         Returns:
#     267             An instance of the RNN_Learner class.
#     268
#     269         """
#     270         m = get_language_model(self.nt, emb_sz, n_hid, n_layers, self.pad_idx, **kwargs)
#     271         model = SingleModel(to_gpu(m))
#     272         return RNN_Learner(self, model, opt_fn=opt_fn)
#     273
#
# ipdb> s
# > /home/zero/fastai/courses/dl1/fastai/nlp.py(270)get_model()
#     268
#     269         """
# --> 270         m = get_language_model(self.nt, emb_sz, n_hid, n_layers, self.pad_idx, **kwargs)
#     271         model = SingleModel(to_gpu(m))
#     272         return RNN_Learner(self, model, opt_fn=opt_fn)
#
# ipdb> s
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(189)get_language_model()
#     187
#     188
# --> 189 def get_language_model(n_tok, emb_sz, nhid, nlayers, pad_token,
#     190                  dropout=0.4, dropouth=0.3, dropouti=0.5, dropoute=0.1, wdrop=0.5, tie_weights=True):
#     191     """Returns a SequentialRNN model.
#
# ipdb> s
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(219)get_language_model()
#     217     """
#     218
# --> 219     rnn_enc = RNN_Encoder(n_tok, emb_sz, nhid=nhid, nlayers=nlayers, pad_token=pad_token,
#     220                  dropouth=dropouth, dropouti=dropouti, dropoute=dropoute, wdrop=wdrop)
#     221     enc = rnn_enc.encoder if tie_weights else None
#
# ipdb> ll
#     189 def get_language_model(n_tok, emb_sz, nhid, nlayers, pad_token,
#     190                  dropout=0.4, dropouth=0.3, dropouti=0.5, dropoute=0.1, wdrop=0.5, tie_weights=True):
#     191     """Returns a SequentialRNN model.
#     192
#     193     A RNN_Encoder layer is instantiated using the parameters provided.
#     194
#     195     This is followed by the creation of a LinearDecoder layer.
#     196
#     197     Also by default (i.e. tie_weights = True), the embedding matrix used in the RNN_Encoder
#     198     is used to  instantiate the weights for the LinearDecoder layer.
#     199
#     200     The SequentialRNN layer is the native torch's Sequential wrapper that puts the RNN_Encoder and
#     201     LinearDecoder layers sequentially in the model.
#     202
#     203     Args:
#     204         ntoken (int): number of vocabulary (or tokens) in the source dataset
#     205         emb_sz (int): the embedding size to use to encode each token
#     206         nhid (int): number of hidden activation per LSTM layer
#     207         nlayers (int): number of LSTM layers to use in the architecture
#     208         pad_token (int): the int value used for padding text.
#     209         dropouth (float): dropout to apply to the activations going from one LSTM layer to another
#     210         dropouti (float): dropout to apply to the input layer.
#     211         dropoute (float): dropout to apply to the embedding layer.
#     212         wdrop (float): dropout used for a LSTM's internal (or hidden) recurrent weights.
#     213         tie_weights (bool): decide if the weights of the embedding matrix in the RNN encoder should be tied to the
#     214             weights of the LinearDecoder layer.
#     215     Returns:
#     216         A SequentialRNN model
#     217     """
#     218
# --> 219     rnn_enc = RNN_Encoder(n_tok, emb_sz, nhid=nhid, nlayers=nlayers, pad_token=pad_token,
#     220                  dropouth=dropouth, dropouti=dropouti, dropoute=dropoute, wdrop=wdrop)
#     221     enc = rnn_enc.encoder if tie_weights else None
#     222     return SequentialRNN(rnn_enc, LinearDecoder(n_tok, emb_sz, dropout, tie_encoder=enc))
#     223
# ipdb> s
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(220)get_language_model()
#     218
#     219     rnn_enc = RNN_Encoder(n_tok, emb_sz, nhid=nhid, nlayers=nlayers, pad_token=pad_token,
# --> 220                  dropouth=dropouth, dropouti=dropouti, dropoute=dropoute, wdrop=wdrop)
#     221     enc = rnn_enc.encoder if tie_weights else None
#     222     return SequentialRNN(rnn_enc, LinearDecoder(n_tok, emb_sz, dropout, tie_encoder=enc))
#
# ipdb> s
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(37)__init__()
#      35     initrange=0.1
#      36
# ---> 37     def __init__(self, ntoken, emb_sz, nhid, nlayers, pad_token, bidir=False,
#      38                  dropouth=0.3, dropouti=0.65, dropoute=0.1, wdrop=0.5):
#      39         """ Default constructor for the RNN_Encoder class
#
# ipdb> ;;
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(57)__init__()
#      55           """
#      56
# ---> 57         super().__init__()
#      58         self.ndir = 2 if bidir else 1
#      59         self.bs = 1
#
# --Call--
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(50)__init__()
#      48     dump_patches = False
#      49
# ---> 50     def __init__(self):
#      51         self._backend = thnn_backend
#      52         self._parameters = OrderedDict()
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(51)__init__()
#      49
#      50     def __init__(self):
# ---> 51         self._backend = thnn_backend
#      52         self._parameters = OrderedDict()
#      53         self._buffers = OrderedDict()
#
# ipdb> ll
#      50     def __init__(self):
# ---> 51         self._backend = thnn_backend
#      52         self._parameters = OrderedDict()
#      53         self._buffers = OrderedDict()
#      54         self._backward_hooks = OrderedDict()
#      55         self._forward_hooks = OrderedDict()
#      56         self._forward_pre_hooks = OrderedDict()
#      57         self._modules = OrderedDict()
#      58         self.training = True
#      59
#
# ipdb> s
# --Call--
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(400)__setattr__()
#     398             type(self).__name__, name))
#     399
# --> 400     def __setattr__(self, name, value):
#     401         def remove_from(*dicts):
#     402             for d in dicts:
#
# ipdb> ll
# --> 400     def __setattr__(self, name, value):
#     401         def remove_from(*dicts):
#     402             for d in dicts:
#     403                 if name in d:
#     404                     del d[name]
#     405
#     406         params = self.__dict__.get('_parameters')
#     407         if isinstance(value, Parameter):
#     408             if params is None:
#     409                 raise AttributeError(
#     410                     "cannot assign parameters before Module.__init__() call")
#     411             remove_from(self.__dict__, self._buffers, self._modules)
#     412             self.register_parameter(name, value)
#     413         elif params is not None and name in params:
#     414             if value is not None:
#     415                 raise TypeError("cannot assign '{}' as parameter '{}' "
#     416                                 "(torch.nn.Parameter or None expected)"
#     417                                 .format(torch.typename(value), name))
#     418             self.register_parameter(name, value)
#     419         else:
#     420             modules = self.__dict__.get('_modules')
#     421             if isinstance(value, Module):
#     422                 if modules is None:
#     423                     raise AttributeError(
#     424                         "cannot assign module before Module.__init__() call")
#     425                 remove_from(self.__dict__, self._parameters, self._buffers)
#     426                 modules[name] = value
#     427             elif modules is not None and name in modules:
#     428                 if value is not None:
#     429                     raise TypeError("cannot assign '{}' as child module '{}' "
#     430                                     "(torch.nn.Module or None expected)"
#     431                                     .format(torch.typename(value), name))
#     432                 modules[name] = value
#     433             else:
#     434                 buffers = self.__dict__.get('_buffers')
#     435                 if buffers is not None and name in buffers:
#     436                     if value is not None and not torch.is_tensor(value):
#     437                         raise TypeError("cannot assign '{}' as buffer '{}' "
#     438                                         "(torch.Tensor or None expected)"
#     439                                         .format(torch.typename(value), name))
#     440                     buffers[name] = value
#     441                 else:
#     442                     object.__setattr__(self, name, value)
#     443
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(401)__setattr__()
#     399
#     400     def __setattr__(self, name, value):
# --> 401         def remove_from(*dicts):
#     402             for d in dicts:
#     403                 if name in d:
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(406)__setattr__()
#     404                     del d[name]
#     405
# --> 406         params = self.__dict__.get('_parameters')
#     407         if isinstance(value, Parameter):
#     408             if params is None:
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(407)__setattr__()
#     405
#     406         params = self.__dict__.get('_parameters')
# --> 407         if isinstance(value, Parameter):
#     408             if params is None:
#     409                 raise AttributeError(
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(413)__setattr__()
#     411             remove_from(self.__dict__, self._buffers, self._modules)
#     412             self.register_parameter(name, value)
# --> 413         elif params is not None and name in params:
#     414             if value is not None:
#     415                 raise TypeError("cannot assign '{}' as parameter '{}' "
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(420)__setattr__()
#     418             self.register_parameter(name, value)
#     419         else:
# --> 420             modules = self.__dict__.get('_modules')
#     421             if isinstance(value, Module):
#     422                 if modules is None:
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(421)__setattr__()
#     419         else:
#     420             modules = self.__dict__.get('_modules')
# --> 421             if isinstance(value, Module):
#     422                 if modules is None:
#     423                     raise AttributeError(
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(427)__setattr__()
#     425                 remove_from(self.__dict__, self._parameters, self._buffers)
#     426                 modules[name] = value
# --> 427             elif modules is not None and name in modules:
#     428                 if value is not None:
#     429                     raise TypeError("cannot assign '{}' as child module '{}' "
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(434)__setattr__()
#     432                 modules[name] = value
#     433             else:
# --> 434                 buffers = self.__dict__.get('_buffers')
#     435                 if buffers is not None and name in buffers:
#     436                     if value is not None and not torch.is_tensor(value):
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(435)__setattr__()
#     433             else:
#     434                 buffers = self.__dict__.get('_buffers')
# --> 435                 if buffers is not None and name in buffers:
#     436                     if value is not None and not torch.is_tensor(value):
#     437                         raise TypeError("cannot assign '{}' as buffer '{}' "
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(442)__setattr__()
#     440                     buffers[name] = value
#     441                 else:
# --> 442                     object.__setattr__(self, name, value)
#     443
#     444     def __delattr__(self, name):
# ipdb> u
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(51)__init__()
#      49
#      50     def __init__(self):
# ---> 51         self._backend = thnn_backend
#      52         self._parameters = OrderedDict()
#      53         self._buffers = OrderedDict()
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(52)__init__()
#      50     def __init__(self):
#      51         self._backend = thnn_backend
# ---> 52         self._parameters = OrderedDict()
#      53         self._buffers = OrderedDict()
#      54         self._backward_hooks = OrderedDict()
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(53)__init__()
#      51         self._backend = thnn_backend
#      52         self._parameters = OrderedDict()
# ---> 53         self._buffers = OrderedDict()
#      54         self._backward_hooks = OrderedDict()
#      55         self._forward_hooks = OrderedDict()
#
# ipdb> u
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(57)__init__()
#      55           """
#      56
# ---> 57         super().__init__()
#      58         self.ndir = 2 if bidir else 1
#      59         self.bs = 1
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(58)__init__()
#      56
#      57         super().__init__()
# ---> 58         self.ndir = 2 if bidir else 1
#      59         self.bs = 1
#      60         self.encoder = nn.Embedding(ntoken, emb_sz, padding_idx=pad_token)
#
# ipdb> s
# --Call--
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(400)__setattr__()
#     398             type(self).__name__, name))
#     399
# --> 400     def __setattr__(self, name, value):
#     401         def remove_from(*dicts):
#     402             for d in dicts:
#
# ipdb> u
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(58)__init__()
#      56
#      57         super().__init__()
# ---> 58         self.ndir = 2 if bidir else 1
#      59         self.bs = 1
#      60         self.encoder = nn.Embedding(ntoken, emb_sz, padding_idx=pad_token)
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(59)__init__()
#      57         super().__init__()
#      58         self.ndir = 2 if bidir else 1
# ---> 59         self.bs = 1
#      60         self.encoder = nn.Embedding(ntoken, emb_sz, padding_idx=pad_token)
#      61         self.encoder_with_dropout = EmbeddingDropout(self.encoder)
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(60)__init__()
#      58         self.ndir = 2 if bidir else 1
#      59         self.bs = 1
# ---> 60         self.encoder = nn.Embedding(ntoken, emb_sz, padding_idx=pad_token)
#      61         self.encoder_with_dropout = EmbeddingDropout(self.encoder)
#      62         self.rnns = [nn.LSTM(emb_sz if l == 0 else nhid, (nhid if l != nlayers - 1 else emb_sz)//self.ndir,
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(61)__init__()
#      59         self.bs = 1
#      60         self.encoder = nn.Embedding(ntoken, emb_sz, padding_idx=pad_token)
# ---> 61         self.encoder_with_dropout = EmbeddingDropout(self.encoder)
#      62         self.rnns = [nn.LSTM(emb_sz if l == 0 else nhid, (nhid if l != nlayers - 1 else emb_sz)//self.ndir,
#      63              1, bidirectional=bidir, dropout=dropouth) for l in range(nlayers)]
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(62)__init__()
#      60         self.encoder = nn.Embedding(ntoken, emb_sz, padding_idx=pad_token)
#      61         self.encoder_with_dropout = EmbeddingDropout(self.encoder)
# ---> 62         self.rnns = [nn.LSTM(emb_sz if l == 0 else nhid, (nhid if l != nlayers - 1 else emb_sz)//self.ndir,
#      63              1, bidirectional=bidir, dropout=dropouth) for l in range(nlayers)]
#      64         if wdrop: self.rnns = [WeightDrop(rnn, wdrop) for rnn in self.rnns]
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(63)__init__()
#      61         self.encoder_with_dropout = EmbeddingDropout(self.encoder)
#      62         self.rnns = [nn.LSTM(emb_sz if l == 0 else nhid, (nhid if l != nlayers - 1 else emb_sz)//self.ndir,
# ---> 63              1, bidirectional=bidir, dropout=dropouth) for l in range(nlayers)]
#      64         if wdrop: self.rnns = [WeightDrop(rnn, wdrop) for rnn in self.rnns]
#      65         self.rnns = torch.nn.ModuleList(self.rnns)
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(64)__init__()
#      62         self.rnns = [nn.LSTM(emb_sz if l == 0 else nhid, (nhid if l != nlayers - 1 else emb_sz)//self.ndir,
#      63              1, bidirectional=bidir, dropout=dropouth) for l in range(nlayers)]
# ---> 64         if wdrop: self.rnns = [WeightDrop(rnn, wdrop) for rnn in self.rnns]
#      65         self.rnns = torch.nn.ModuleList(self.rnns)
#      66         self.encoder.weight.data.uniform_(-self.initrange, self.initrange)
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(65)__init__()
#      63              1, bidirectional=bidir, dropout=dropouth) for l in range(nlayers)]
#      64         if wdrop: self.rnns = [WeightDrop(rnn, wdrop) for rnn in self.rnns]
# ---> 65         self.rnns = torch.nn.ModuleList(self.rnns)
#      66         self.encoder.weight.data.uniform_(-self.initrange, self.initrange)
#      67
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(66)__init__()
#      64         if wdrop: self.rnns = [WeightDrop(rnn, wdrop) for rnn in self.rnns]
#      65         self.rnns = torch.nn.ModuleList(self.rnns)
# ---> 66         self.encoder.weight.data.uniform_(-self.initrange, self.initrange)
#      67
#      68         self.emb_sz,self.nhid,self.nlayers,self.dropoute = emb_sz,nhid,nlayers,dropoute
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(68)__init__()
#      66         self.encoder.weight.data.uniform_(-self.initrange, self.initrange)
#      67
# ---> 68         self.emb_sz,self.nhid,self.nlayers,self.dropoute = emb_sz,nhid,nlayers,dropoute
#      69         self.dropouti = LockedDropout(dropouti)
#      70         self.dropouths = nn.ModuleList([LockedDropout(dropouth) for l in range(nlayers)])
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(69)__init__()
#      67
#      68         self.emb_sz,self.nhid,self.nlayers,self.dropoute = emb_sz,nhid,nlayers,dropoute
# ---> 69         self.dropouti = LockedDropout(dropouti)
#      70         self.dropouths = nn.ModuleList([LockedDropout(dropouth) for l in range(nlayers)])
#      71
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(70)__init__()
#      68         self.emb_sz,self.nhid,self.nlayers,self.dropoute = emb_sz,nhid,nlayers,dropoute
#      69         self.dropouti = LockedDropout(dropouti)
# ---> 70         self.dropouths = nn.ModuleList([LockedDropout(dropouth) for l in range(nlayers)])
#      71
#      72     def forward(self, input):
# ipdb> n
# --Return--
# None
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(70)__init__()
#      68         self.emb_sz,self.nhid,self.nlayers,self.dropoute = emb_sz,nhid,nlayers,dropoute
#      69         self.dropouti = LockedDropout(dropouti)
# ---> 70         self.dropouths = nn.ModuleList([LockedDropout(dropouth) for l in range(nlayers)])
#      71
#      72     def forward(self, input):
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(221)get_language_model()
#     219     rnn_enc = RNN_Encoder(n_tok, emb_sz, nhid=nhid, nlayers=nlayers, pad_token=pad_token,
#     220                  dropouth=dropouth, dropouti=dropouti, dropoute=dropoute, wdrop=wdrop)
# --> 221     enc = rnn_enc.encoder if tie_weights else None
#     222     return SequentialRNN(rnn_enc, LinearDecoder(n_tok, emb_sz, dropout, tie_encoder=enc))
#     223
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(222)get_language_model()
#     220                  dropouth=dropouth, dropouti=dropouti, dropoute=dropoute, wdrop=wdrop)
#     221     enc = rnn_enc.encoder if tie_weights else None
# --> 222     return SequentialRNN(rnn_enc, LinearDecoder(n_tok, emb_sz, dropout, tie_encoder=enc))
#     223
#     224
#
# ipdb> s
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(135)__init__()
#     133 class LinearDecoder(nn.Module):
#     134     initrange=0.1
# --> 135     def __init__(self, n_out, nhid, dropout, tie_encoder=None):
#     136         super().__init__()
#     137         self.decoder = nn.Linear(nhid, n_out, bias=False)
#
# ipdb> ll
# --> 135     def __init__(self, n_out, nhid, dropout, tie_encoder=None):
#     136         super().__init__()
#     137         self.decoder = nn.Linear(nhid, n_out, bias=False)
#     138         self.decoder.weight.data.uniform_(-self.initrange, self.initrange)
#     139         self.dropout = LockedDropout(dropout)
#     140         if tie_encoder: self.decoder.weight = tie_encoder.weight
#     141
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(136)__init__()
#     134     initrange=0.1
#     135     def __init__(self, n_out, nhid, dropout, tie_encoder=None):
# --> 136         super().__init__()
#     137         self.decoder = nn.Linear(nhid, n_out, bias=False)
#     138         self.decoder.weight.data.uniform_(-self.initrange, self.initrange)
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(137)__init__()
#     135     def __init__(self, n_out, nhid, dropout, tie_encoder=None):
#     136         super().__init__()
# --> 137         self.decoder = nn.Linear(nhid, n_out, bias=False)
#     138         self.decoder.weight.data.uniform_(-self.initrange, self.initrange)
#     139         self.dropout = LockedDropout(dropout)
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(138)__init__()
#     136         super().__init__()
#     137         self.decoder = nn.Linear(nhid, n_out, bias=False)
# --> 138         self.decoder.weight.data.uniform_(-self.initrange, self.initrange)
#     139         self.dropout = LockedDropout(dropout)
#     140         if tie_encoder: self.decoder.weight = tie_encoder.weight
# ipdb> u
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(222)get_language_model()
#     220                  dropouth=dropouth, dropouti=dropouti, dropoute=dropoute, wdrop=wdrop)
#     221     enc = rnn_enc.encoder if tie_weights else None
# --> 222     return SequentialRNN(rnn_enc, LinearDecoder(n_tok, emb_sz, dropout, tie_encoder=enc))
#     223
#     224
#
# ipdb> n
# --Return--
# SequentialRNN...t(
#     )
#   )
# )
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(222)get_language_model()
#     220                  dropouth=dropouth, dropouti=dropouti, dropoute=dropoute, wdrop=wdrop)
#     221     enc = rnn_enc.encoder if tie_weights else None
# --> 222     return SequentialRNN(rnn_enc, LinearDecoder(n_tok, emb_sz, dropout, tie_encoder=enc))
#     223
#     224
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/nlp.py(271)get_model()
#     269         """
#     270         m = get_language_model(self.nt, emb_sz, n_hid, n_layers, self.pad_idx, **kwargs)
# --> 271         model = SingleModel(to_gpu(m))
#     272         return RNN_Learner(self, model, opt_fn=opt_fn)
#     273
#
# ipdb> s
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/core.py(40)to_gpu()
#      38
#      39 USE_GPU=True
# ---> 40 def to_gpu(x, *args, **kwargs):
#      41     return x.cuda(*args, **kwargs) if torch.cuda.is_available() and USE_GPU else x
#      42
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/core.py(41)to_gpu()
#      39 USE_GPU=True
#      40 def to_gpu(x, *args, **kwargs):
# ---> 41     return x.cuda(*args, **kwargs) if torch.cuda.is_available() and USE_GPU else x
#      42
#      43 def noop(*args, **kwargs): return
#
# ipdb> n
# --Return--
# SequentialRNN...t(
#     )
#   )
# )
# > /home/zero/fastai/courses/dl1/fastai/core.py(41)to_gpu()
#      39 USE_GPU=True
#      40 def to_gpu(x, *args, **kwargs):
# ---> 41     return x.cuda(*args, **kwargs) if torch.cuda.is_available() and USE_GPU else x
#      42
#      43 def noop(*args, **kwargs): return
#
# ipdb> n
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/core.py(91)__init__()
#      89
#      90 class BasicModel():
# ---> 91     def __init__(self,model,name='unnamed'): self.model,self.name = model,name
#      92     def get_layer_groups(self, do_fc=False): return children(self.model)
#      93
#
# ipdb> ll
# ---> 91     def __init__(self,model,name='unnamed'): self.model,self.name = model,name
#      92     def get_layer_groups(self, do_fc=False): return children(self.model)
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/core.py(91)__init__()
#      89
#      90 class BasicModel():
# ---> 91     def __init__(self,model,name='unnamed'): self.model,self.name = model,name
#      92     def get_layer_groups(self, do_fc=False): return children(self.model)
#      93
#
# ipdb> n
# --Return--
# None
# > /home/zero/fastai/courses/dl1/fastai/core.py(91)__init__()
#      89
#      90 class BasicModel():
# ---> 91     def __init__(self,model,name='unnamed'): self.model,self.name = model,name
#      92     def get_layer_groups(self, do_fc=False): return children(self.model)
#      93
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/nlp.py(272)get_model()
#     270         m = get_language_model(self.nt, emb_sz, n_hid, n_layers, self.pad_idx, **kwargs)
#     271         model = SingleModel(to_gpu(m))
# --> 272         return RNN_Learner(self, model, opt_fn=opt_fn)
#     273
#     274     @classmethod
#
# ipdb> s
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/nlp.py(156)__init__()
#     154
#     155 class RNN_Learner(Learner):
# --> 156     def __init__(self, data, models, **kwargs):
#     157         super().__init__(data, models, **kwargs)
#     158         self.crit = F.cross_entropy
#
# ipdb> ll
# --> 156     def __init__(self, data, models, **kwargs):
#     157         super().__init__(data, models, **kwargs)
#     158         self.crit = F.cross_entropy
#     159
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/nlp.py(157)__init__()
#     155 class RNN_Learner(Learner):
#     156     def __init__(self, data, models, **kwargs):
# --> 157         super().__init__(data, models, **kwargs)
#     158         self.crit = F.cross_entropy
#     159
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/nlp.py(158)__init__()
#     156     def __init__(self, data, models, **kwargs):
#     157         super().__init__(data, models, **kwargs)
# --> 158         self.crit = F.cross_entropy
#     159
#     160     def save_encoder(self, name): save_model(self.model[0], self.get_model_path(name))
#
# ipdb> n
# --Return--
# None
# > /home/zero/fastai/courses/dl1/fastai/nlp.py(158)__init__()
#     156     def __init__(self, data, models, **kwargs):
#     157         super().__init__(data, models, **kwargs)
# --> 158         self.crit = F.cross_entropy
#     159
#     160     def save_encoder(self, name): save_model(self.model[0], self.get_model_path(name))
#
# ipdb> n
# --Return--
# SequentialRNN...t(
#     )
#   )
# )
# > /home/zero/fastai/courses/dl1/fastai/nlp.py(272)get_model()
#     270         m = get_language_model(self.nt, emb_sz, n_hid, n_layers, self.pad_idx, **kwargs)
#     271         model = SingleModel(to_gpu(m))
# --> 272         return RNN_Learner(self, model, opt_fn=opt_fn)
#     273
#     274     @classmethod
#
# ipdb> n
# --Return--
# None
# > <string>(9)<module>()
#
# ipdb> n

# %%
learner = md.get_model(opt_fn, em_sz, nh, nl, dropouti=0.05, dropout=0.05, wdrop=0.1, dropoute=0.02, dropouth=0.05)
learner.reg_fn = partial(seq2seq_reg, alpha=2, beta=1)
learner.clip=0.3

# %% [markdown]
# As you can see below, I gradually tuned the language model in a few stages. I possibly could have trained it further (it wasn't yet overfitting), but I didn't have time to experiment more. Maybe you can see if you can train it to a better accuracy! (I used `lr_find` to find a good learning rate, but didn't save the output in this notebook. Feel free to try running it yourself now.)

# %%
learner.fit(3e-3, 1, wds=1e-6) #,, cycle_len=1, cycle_mult=2
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# epoch      trn_loss   val_loss
#     0      5.768159   5.626659
# [5.626659]

# %%
learner.save_encoder('adam1_enc')

# %%
learner.load_encoder('adam1_enc')

# %%
learner.load_cycle('adam3_10',2)

# %%
learner.fit(3e-3, 1, wds=1e-6, cycle_len=10)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# [ 0.      4.3926  4.2917]
# [ 1.       4.37693  4.28255]
# [ 2.       4.37998  4.27243]
# [ 3.       4.34284  4.24789]
# [ 4.      4.3287  4.2317]
# [ 5.       4.28881  4.20722]
# [ 6.       4.24637  4.18926]
# [ 7.       4.23797  4.17644]
# [ 8.       4.20074  4.16989]
# [ 9.       4.18873  4.16866]

# %%
learner.save_encoder('adam3_10_enc')

# %% [markdown]
# In the sentiment analysis section, we'll just need half of the language model - the *encoder*, so we save that part.

# %%
learner.save_encoder('adam3_20_enc')

# %%
learner.load_encoder('adam3_20_enc')

# %% [markdown]
# Language modeling accuracy is generally measured using the metric *perplexity*, which is simply `exp()` of the loss function we used.

# %%
math.exp(4.165)
# Out:
# 64.3926824434624

# %%
pickle.dump(TEXT, open(f'{PATH}models/TEXT.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-121-1589b40f7022> in <module>()
# ----> 1 pickle.dump(TEXT, open(f'{PATH}models/TEXT.pkl','wb'))
#
# ~/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/dill/dill.py in dump(obj, file, protocol, byref, fmode, recurse)
#     272         raise PicklingError(msg)
#     273     else:
# --> 274         pik.dump(obj)
#     275     stack.clear()  # clear record of 'recursion-sensitive' pickled objects
#     276     return
#
# ~/anaconda/envs/fastai-cpu/lib/python3.6/pickle.py in dump(self, obj)
#     407         if self.proto >= 4:
#     408             self.framer.start_framing()
# --> 409         self.save(obj)
#     410         self.write(STOP)
#     411         self.framer.end_framing()
#
# ~/anaconda/envs/fastai-cpu/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# ~/anaconda/envs/fastai-cpu/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     603                     "args[0] from __newobj__ args has the wrong class")
#     604             args = args[1:]
# --> 605             save(cls)
#     606             save(args)
#     607             write(NEWOBJ)
#
# ~/anaconda/envs/fastai-cpu/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/dill/dill.py in save_type(pickler, obj)
#    1297        #print ("%s\n%s" % (type(obj), obj.__name__))
#    1298        #print ("%s\n%s" % (obj.__bases__, obj.__dict__))
# -> 1299         StockPickler.save_global(pickler, obj)
#    1300         log.info("# T4")
#    1301     return
#
# ~/anaconda/envs/fastai-cpu/lib/python3.6/pickle.py in save_global(self, obj, name)
#     925                 raise PicklingError(
#     926                     "Can't pickle %r: it's not the same object as %s.%s" %
# --> 927                     (obj, module_name, name))
#     928
#     929         if self.proto >= 2:
#
# PicklingError: Can't pickle <class 'torchtext.data.field.Field'>: it's not the same object as torchtext.data.field.Field

# %% [markdown]
# ### Test

# %% [markdown]
# We can play around with our language model a bit to check it seems to be working OK. First, let's create a short bit of text to 'prime' a set of predictions. We'll use our torchtext field to numericalize it so we can feed it to our language model.

# %% [markdown]
# We haven't yet added methods to make it easy to test a language model, so we'll need to manually go through the steps.

# %%
# Set batch size to 1
m[0].bs=1
# Turn off dropout
m.eval()
# Reset hidden state
m.reset()
# Get predictions from model
res,*_ = m(t)
# Put the batch size back to what it was
m[0].bs=bs

# %% [markdown]
# Let's see what the top 10 predictions were for the next word after our short text:

# %%
nexts = torch.topk(res[-1], 10)[1]
[TEXT.vocab.itos[o] for o in to_np(nexts)]
# Out:
# ['.', ',', '\n', '<eos>', '<unk>', 'luôn', 'nhưng', 'mà', 'nên', 'nha']

# %% [markdown]
# ...and let's see if our model can generate a bit more text all by itself!

# %%
res[-1].topk(2)
# Out:
# (Variable containing:
#   7.5100
#   6.7214
#  [torch.FloatTensor of size 2], Variable containing:
#     2
#   153
#  [torch.LongTensor of size 2])

# %%
n = n[1] if n.data[0]==0 else n[0] #if is unknow then choose the second

# %%
ida = 102

# %%
TEXT.vocab.itos[ida]
# Out:
# 'nhất'

# %%
a= m(V(ida).unsqueeze(0))[0][-1].topk(2)[1]

# %%
a = a[1] if a.data[0]==0 else a[0]

# %%
TEXT.vocab.itos[a.data[0]]
# Out:
# '.'

# %%
m=learner.model
ss="""quán steak hiếm hoi mà mình cực kì ưng ý từ lâu lắm rồi mới có dịp đi ăn""" # 
s = [spacy_tok(ss)]
t=TEXT.numericalize(s)
' '.join(s[0])
# Out:
# 'quán steak hiếm hoi mà mình cực kì ưng ý từ lâu lắm rồi mới có dịp đi ăn'

# %%
# Set batch size to 1
m[0].bs=1
# Turn off dropout
m.eval()
# Reset hidden state
m.reset()

# %%
# %debug m(t)
# Out:
# NOTE: Enter 'c' at the ipdb>  prompt to continue execution.
# None
# > <string>(1)<module>()
#
# ipdb> s
# --Call--
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(351)__call__()
#     349         return result
#     350
# --> 351     def __call__(self, *input, **kwargs):
#     352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(352)__call__()
#     350
#     351     def __call__(self, *input, **kwargs):
# --> 352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
#     354         if torch.jit._tracing:
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(354)__call__()
#     352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
# --> 354         if torch.jit._tracing:
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(357)__call__()
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ipdb> ll
#     351     def __call__(self, *input, **kwargs):
#     352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
#     354         if torch.jit._tracing:
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#     360             if hook_result is not None:
#     361                 raise RuntimeError(
#     362                     "forward hooks should never return any values, but '{}'"
#     363                     "didn't return None".format(hook))
#     364         if len(self._backward_hooks) > 0:
#     365             var = result
#     366             while not isinstance(var, Variable):
#     367                 if isinstance(var, dict):
#     368                     var = next((v for v in var.values() if isinstance(v, Variable)))
#     369                 else:
#     370                     var = var[0]
#     371             grad_fn = var.grad_fn
#     372             if grad_fn is not None:
#     373                 for hook in self._backward_hooks.values():
#     374                     wrapper = functools.partial(hook, self)
#     375                     functools.update_wrapper(wrapper, hook)
#     376                     grad_fn.register_hook(wrapper)
#     377         return result
#     378
#
# ipdb> s
# --Call--
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/container.py(65)forward()
#      63         return len(self._modules)
#      64
# ---> 65     def forward(self, input):
#      66         for module in self._modules.values():
#      67             input = module(input)
# ipdb> ll
# ---> 65     def forward(self, input):
#      66         for module in self._modules.values():
#      67             input = module(input)
#      68         return input
#      69
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/container.py(66)forward()
#      64
#      65     def forward(self, input):
# ---> 66         for module in self._modules.values():
#      67             input = module(input)
#      68         return input
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/container.py(67)forward()
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ipdb> s
# --Call--
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(351)__call__()
#     349         return result
#     350
# --> 351     def __call__(self, *input, **kwargs):
#     352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
#
# ipdb> ll
# --> 351     def __call__(self, *input, **kwargs):
#     352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
#     354         if torch.jit._tracing:
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
#     357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#     360             if hook_result is not None:
#     361                 raise RuntimeError(
#     362                     "forward hooks should never return any values, but '{}'"
#     363                     "didn't return None".format(hook))
#     364         if len(self._backward_hooks) > 0:
#     365             var = result
#     366             while not isinstance(var, Variable):
#     367                 if isinstance(var, dict):
#     368                     var = next((v for v in var.values() if isinstance(v, Variable)))
#     369                 else:
#     370                     var = var[0]
#     371             grad_fn = var.grad_fn
#     372             if grad_fn is not None:
#     373                 for hook in self._backward_hooks.values():
#     374                     wrapper = functools.partial(hook, self)
#     375                     functools.update_wrapper(wrapper, hook)
#     376                     grad_fn.register_hook(wrapper)
#     377         return result
#     378
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(352)__call__()
#     350
#     351     def __call__(self, *input, **kwargs):
# --> 352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
#     354         if torch.jit._tracing:
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(354)__call__()
#     352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
# --> 354         if torch.jit._tracing:
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(357)__call__()
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ipdb> s
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(72)forward()
#      70         self.dropouths = nn.ModuleList([LockedDropout(dropouth) for l in range(nlayers)])
#      71
# ---> 72     def forward(self, input):
#      73         """ Invoked during the forward propagation of the RNN_Encoder module.
#      74         Args:
#
# ipdb> ll
# ---> 72     def forward(self, input):
#      73         """ Invoked during the forward propagation of the RNN_Encoder module.
#      74         Args:
#      75             input (Tensor): input of shape (batch_size x sentence length)
#      76
#      77         Returns:
#      78             raw_outputs (tuple(list (Tensor), list(Tensor)): list of tensors evaluated from each RNN layer without using
#      79             dropouth, list of tensors evaluated from each RNN layer using dropouth,
#      80         """
#      81         sl,bs = input.size()
#      82         if bs!=self.bs:
#      83             self.bs=bs
#      84             self.reset()
#      85
#      86         emb = self.encoder_with_dropout(input, dropout=self.dropoute if self.training else 0)
#      87         emb = self.dropouti(emb)
#      88
#      89         raw_output = emb
#      90         new_hidden,raw_outputs,outputs = [],[],[]
#      91         for l, (rnn,drop) in enumerate(zip(self.rnns, self.dropouths)):
#      92             current_input = raw_output
#      93             with warnings.catch_warnings():
#      94                 warnings.simplefilter("ignore")
#      95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
#      96             new_hidden.append(new_h)
#      97             raw_outputs.append(raw_output)
#      98             if l != self.nlayers - 1: raw_output = drop(raw_output)
#      99             outputs.append(raw_output)
#     100
#     101         self.hidden = repackage_var(new_hidden)
#     102         return raw_outputs, outputs
#     103
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(81)forward()
#      79             dropouth, list of tensors evaluated from each RNN layer using dropouth,
#      80         """
# ---> 81         sl,bs = input.size()
#      82         if bs!=self.bs:
#      83             self.bs=bs
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(82)forward()
#      80         """
#      81         sl,bs = input.size()
# ---> 82         if bs!=self.bs:
#      83             self.bs=bs
#      84             self.reset()
#
# ipdb> sl
# 19
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(86)forward()
#      84             self.reset()
#      85
# ---> 86         emb = self.encoder_with_dropout(input, dropout=self.dropoute if self.training else 0)
#      87         emb = self.dropouti(emb)
#      88
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(87)forward()
#      85
#      86         emb = self.encoder_with_dropout(input, dropout=self.dropoute if self.training else 0)
# ---> 87         emb = self.dropouti(emb)
#      88
#      89         raw_output = emb
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(89)forward()
#      87         emb = self.dropouti(emb)
#      88
# ---> 89         raw_output = emb
#      90         new_hidden,raw_outputs,outputs = [],[],[]
#      91         for l, (rnn,drop) in enumerate(zip(self.rnns, self.dropouths)):
#
# ipdb> emb.size()
# torch.Size([19, 1, 20])
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(90)forward()
#      88
#      89         raw_output = emb
# ---> 90         new_hidden,raw_outputs,outputs = [],[],[]
#      91         for l, (rnn,drop) in enumerate(zip(self.rnns, self.dropouths)):
#      92             current_input = raw_output
#
# ipdb> ll
#      72     def forward(self, input):
#      73         """ Invoked during the forward propagation of the RNN_Encoder module.
#      74         Args:
#      75             input (Tensor): input of shape (batch_size x sentence length)
#      76
#      77         Returns:
#      78             raw_outputs (tuple(list (Tensor), list(Tensor)): list of tensors evaluated from each RNN layer without using
#      79             dropouth, list of tensors evaluated from each RNN layer using dropouth,
#      80         """
#      81         sl,bs = input.size()
#      82         if bs!=self.bs:
#      83             self.bs=bs
#      84             self.reset()
#      85
#      86         emb = self.encoder_with_dropout(input, dropout=self.dropoute if self.training else 0)
#      87         emb = self.dropouti(emb)
#      88
#      89         raw_output = emb
# ---> 90         new_hidden,raw_outputs,outputs = [],[],[]
#      91         for l, (rnn,drop) in enumerate(zip(self.rnns, self.dropouths)):
#      92             current_input = raw_output
#      93             with warnings.catch_warnings():
#      94                 warnings.simplefilter("ignore")
#      95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
#      96             new_hidden.append(new_h)
#      97             raw_outputs.append(raw_output)
#      98             if l != self.nlayers - 1: raw_output = drop(raw_output)
#      99             outputs.append(raw_output)
#     100
#     101         self.hidden = repackage_var(new_hidden)
#     102         return raw_outputs, outputs
#     103
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(91)forward()
#      89         raw_output = emb
#      90         new_hidden,raw_outputs,outputs = [],[],[]
# ---> 91         for l, (rnn,drop) in enumerate(zip(self.rnns, self.dropouths)):
#      92             current_input = raw_output
#      93             with warnings.catch_warnings():
#
# ipdb> s
# --Call--
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(384)__getattr__()
#     382             self._forward_pre_hooks = OrderedDict()
#     383
# --> 384     def __getattr__(self, name):
#     385         if '_parameters' in self.__dict__:
#     386             _parameters = self.__dict__['_parameters']
# ipdb> u
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(91)forward()
#      89         raw_output = emb
#      90         new_hidden,raw_outputs,outputs = [],[],[]
# ---> 91         for l, (rnn,drop) in enumerate(zip(self.rnns, self.dropouths)):
#      92             current_input = raw_output
#      93             with warnings.catch_warnings():
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(92)forward()
#      90         new_hidden,raw_outputs,outputs = [],[],[]
#      91         for l, (rnn,drop) in enumerate(zip(self.rnns, self.dropouths)):
# ---> 92             current_input = raw_output
#      93             with warnings.catch_warnings():
#      94                 warnings.simplefilter("ignore")
#
# ipdb> raw_output.size()
# torch.Size([19, 1, 20])
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(93)forward()
#      91         for l, (rnn,drop) in enumerate(zip(self.rnns, self.dropouths)):
#      92             current_input = raw_output
# ---> 93             with warnings.catch_warnings():
#      94                 warnings.simplefilter("ignore")
#      95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
#
# ipdb> self.hidden[l]
# (Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 8
#    0.0442 -0.0321  0.0275  0.0765  0.0259 -0.0851  0.0561  0.0562 -0.0490
#
# Columns 9 to 17
#    0.0796  0.1238 -0.0084  0.0817  0.0627  0.0081  0.0837  0.0294 -0.0774
#
# Columns 18 to 26
#   -0.0091  0.1209 -0.1500  0.0010  0.0535  0.1974  0.0960 -0.0031  0.1180
#
# Columns 27 to 35
#   -0.0166  0.1620 -0.0534  0.0760 -0.0001  0.0030 -0.0915  0.1087  0.0415
#
# Columns 36 to 44
#    0.0417 -0.1289 -0.2170 -0.0240  0.0730 -0.0698 -0.1602 -0.1231 -0.0672
#
# Columns 45 to 49
#   -0.0341  0.1297 -0.0771 -0.0006 -0.0106
# [torch.FloatTensor of size 1x1x50]
# , Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 8
#    0.0981 -0.1048  0.1103  0.1592  0.0981 -0.1869  0.0825  0.1477 -0.1041
#
# Columns 9 to 17
#    0.1242  0.3674 -0.0313  0.1732  0.1677  0.0232  0.2449  0.1831 -0.1468
#
# Columns 18 to 26
#   -0.0158  0.2473 -0.2689  0.0024  0.1316  0.4117  0.2161 -0.0075  0.2389
#
# Columns 27 to 35
#   -0.0482  0.2401 -0.1951  0.2428 -0.0002  0.0098 -0.1706  0.2301  0.1779
#
# Columns 36 to 44
#    0.0919 -0.3390 -0.3941 -0.0918  0.1917 -0.2564 -0.3814 -0.2366 -0.2095
#
# Columns 45 to 49
#   -0.1163  0.2835 -0.2112 -0.0014 -0.0197
# [torch.FloatTensor of size 1x1x50]
# )
# ipdb> self.hidden[l].size()
# *** AttributeError: 'tuple' object has no attribute 'size'
# ipdb> len(self.hidden[l])
# 2
# ipdb> self.hidden[l].size()
# *** AttributeError: 'tuple' object has no attribute 'size'
# ipdb> self.hidden[l][0].size()
# torch.Size([1, 1, 50])
# ipdb> self.hidden[l][1].size()
# torch.Size([1, 1, 50])
# ipdb> ll
#      72     def forward(self, input):
#      73         """ Invoked during the forward propagation of the RNN_Encoder module.
#      74         Args:
#      75             input (Tensor): input of shape (batch_size x sentence length)
#      76
#      77         Returns:
#      78             raw_outputs (tuple(list (Tensor), list(Tensor)): list of tensors evaluated from each RNN layer without using
#      79             dropouth, list of tensors evaluated from each RNN layer using dropouth,
#      80         """
#      81         sl,bs = input.size()
#      82         if bs!=self.bs:
#      83             self.bs=bs
#      84             self.reset()
#      85
#      86         emb = self.encoder_with_dropout(input, dropout=self.dropoute if self.training else 0)
#      87         emb = self.dropouti(emb)
#      88
#      89         raw_output = emb
#      90         new_hidden,raw_outputs,outputs = [],[],[]
#      91         for l, (rnn,drop) in enumerate(zip(self.rnns, self.dropouths)):
#      92             current_input = raw_output
# ---> 93             with warnings.catch_warnings():
#      94                 warnings.simplefilter("ignore")
#      95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
#      96             new_hidden.append(new_h)
#      97             raw_outputs.append(raw_output)
#      98             if l != self.nlayers - 1: raw_output = drop(raw_output)
#      99             outputs.append(raw_output)
#     100
#     101         self.hidden = repackage_var(new_hidden)
#     102         return raw_outputs, outputs
#     103
# ipdb> current_input.size()
# torch.Size([19, 1, 20])
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(94)forward()
#      92             current_input = raw_output
#      93             with warnings.catch_warnings():
# ---> 94                 warnings.simplefilter("ignore")
#      95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
#      96             new_hidden.append(new_h)
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(95)forward()
#      93             with warnings.catch_warnings():
#      94                 warnings.simplefilter("ignore")
# ---> 95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
#      96             new_hidden.append(new_h)
#      97             raw_outputs.append(raw_output)
#
# ipdb> s
# --Call--
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(351)__call__()
#     349         return result
#     350
# --> 351     def __call__(self, *input, **kwargs):
#     352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(352)__call__()
#     350
#     351     def __call__(self, *input, **kwargs):
# --> 352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
#     354         if torch.jit._tracing:
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(354)__call__()
#     352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
# --> 354         if torch.jit._tracing:
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(357)__call__()
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ipdb> s
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/rnn_reg.py(109)forward()
#     107             setattr(self.module, name_w, w)
#     108
# --> 109     def forward(self, *args):
#     110         """ updates weights and delegates the propagation of the tensor to the wrapped module's
#     111         forward method
#
# ipdb> ll
# --> 109     def forward(self, *args):
#     110         """ updates weights and delegates the propagation of the tensor to the wrapped module's
#     111         forward method
#     112
#     113         Args:
#     114             *args: supplied arguments
#     115
#     116         Returns:
#     117             tensor obtained by running the forward method on the wrapped module.
#     118         """
#     119         self._setweights()
#     120         return self.module.forward(*args)
#     121
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/rnn_reg.py(119)forward()
#     117             tensor obtained by running the forward method on the wrapped module.
#     118         """
# --> 119         self._setweights()
#     120         return self.module.forward(*args)
#     121
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/rnn_reg.py(120)forward()
#     118         """
#     119         self._setweights()
# --> 120         return self.module.forward(*args)
#     121
#     122 class EmbeddingDropout(nn.Module):
# ipdb> s
# --Call--
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(384)__getattr__()
#     382             self._forward_pre_hooks = OrderedDict()
#     383
# --> 384     def __getattr__(self, name):
#     385         if '_parameters' in self.__dict__:
#     386             _parameters = self.__dict__['_parameters']
#
# ipdb> ll
# --> 384     def __getattr__(self, name):
#     385         if '_parameters' in self.__dict__:
#     386             _parameters = self.__dict__['_parameters']
#     387             if name in _parameters:
#     388                 return _parameters[name]
#     389         if '_buffers' in self.__dict__:
#     390             _buffers = self.__dict__['_buffers']
#     391             if name in _buffers:
#     392                 return _buffers[name]
#     393         if '_modules' in self.__dict__:
#     394             modules = self.__dict__['_modules']
#     395             if name in modules:
#     396                 return modules[name]
#     397         raise AttributeError("'{}' object has no attribute '{}'".format(
#     398             type(self).__name__, name))
#     399
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(385)__getattr__()
#     383
#     384     def __getattr__(self, name):
# --> 385         if '_parameters' in self.__dict__:
#     386             _parameters = self.__dict__['_parameters']
#     387             if name in _parameters:
#
# ipdb> u
# > /home/zero/fastai/courses/dl1/fastai/rnn_reg.py(120)forward()
#     118         """
#     119         self._setweights()
# --> 120         return self.module.forward(*args)
#     121
#     122 class EmbeddingDropout(nn.Module):
#
# ipdb> n
# --Return--
# (Variable cont...size 19x1x50]
# , (Variable cont... size 1x1x50]
# , Variable cont... size 1x1x50]
# ))
# > /home/zero/fastai/courses/dl1/fastai/rnn_reg.py(120)forward()
#     118         """
#     119         self._setweights()
# --> 120         return self.module.forward(*args)
#     121
#     122 class EmbeddingDropout(nn.Module):
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(358)__call__()
#     356         else:
#     357             result = self.forward(*input, **kwargs)
# --> 358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#     360             if hook_result is not None:
#
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(364)__call__()
#     362                     "forward hooks should never return any values, but '{}'"
#     363                     "didn't return None".format(hook))
# --> 364         if len(self._backward_hooks) > 0:
#     365             var = result
#     366             while not isinstance(var, Variable):
#
# ipdb> ll
#     351     def __call__(self, *input, **kwargs):
#     352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
#     354         if torch.jit._tracing:
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
#     357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#     360             if hook_result is not None:
#     361                 raise RuntimeError(
#     362                     "forward hooks should never return any values, but '{}'"
#     363                     "didn't return None".format(hook))
# --> 364         if len(self._backward_hooks) > 0:
#     365             var = result
#     366             while not isinstance(var, Variable):
#     367                 if isinstance(var, dict):
#     368                     var = next((v for v in var.values() if isinstance(v, Variable)))
#     369                 else:
#     370                     var = var[0]
#     371             grad_fn = var.grad_fn
#     372             if grad_fn is not None:
#     373                 for hook in self._backward_hooks.values():
#     374                     wrapper = functools.partial(hook, self)
#     375                     functools.update_wrapper(wrapper, hook)
#     376                     grad_fn.register_hook(wrapper)
#     377         return result
#     378
# ipdb> u
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(95)forward()
#      93             with warnings.catch_warnings():
#      94                 warnings.simplefilter("ignore")
# ---> 95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
#      96             new_hidden.append(new_h)
#      97             raw_outputs.append(raw_output)
#
# ipdb> raw_output.size()
# torch.Size([19, 1, 20])
# ipdb> ll
#      72     def forward(self, input):
#      73         """ Invoked during the forward propagation of the RNN_Encoder module.
#      74         Args:
#      75             input (Tensor): input of shape (batch_size x sentence length)
#      76
#      77         Returns:
#      78             raw_outputs (tuple(list (Tensor), list(Tensor)): list of tensors evaluated from each RNN layer without using
#      79             dropouth, list of tensors evaluated from each RNN layer using dropouth,
#      80         """
#      81         sl,bs = input.size()
#      82         if bs!=self.bs:
#      83             self.bs=bs
#      84             self.reset()
#      85
#      86         emb = self.encoder_with_dropout(input, dropout=self.dropoute if self.training else 0)
#      87         emb = self.dropouti(emb)
#      88
#      89         raw_output = emb
#      90         new_hidden,raw_outputs,outputs = [],[],[]
#      91         for l, (rnn,drop) in enumerate(zip(self.rnns, self.dropouths)):
#      92             current_input = raw_output
#      93             with warnings.catch_warnings():
#      94                 warnings.simplefilter("ignore")
# ---> 95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
#      96             new_hidden.append(new_h)
#      97             raw_outputs.append(raw_output)
#      98             if l != self.nlayers - 1: raw_output = drop(raw_output)
#      99             outputs.append(raw_output)
#     100
#     101         self.hidden = repackage_var(new_hidden)
#     102         return raw_outputs, outputs
#     103
#
# ipdb> raw_output.size()
# torch.Size([19, 1, 20])
# ipdb> new_h.size()
# *** NameError: name 'new_h' is not defined
# ipdb> s
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(377)__call__()
#     375                     functools.update_wrapper(wrapper, hook)
#     376                     grad_fn.register_hook(wrapper)
# --> 377         return result
#     378
#     379     def __setstate__(self, state):
#
# ipdb> ll
#     351     def __call__(self, *input, **kwargs):
#     352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
#     354         if torch.jit._tracing:
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
#     357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#     360             if hook_result is not None:
#     361                 raise RuntimeError(
#     362                     "forward hooks should never return any values, but '{}'"
#     363                     "didn't return None".format(hook))
#     364         if len(self._backward_hooks) > 0:
#     365             var = result
#     366             while not isinstance(var, Variable):
#     367                 if isinstance(var, dict):
#     368                     var = next((v for v in var.values() if isinstance(v, Variable)))
#     369                 else:
#     370                     var = var[0]
#     371             grad_fn = var.grad_fn
#     372             if grad_fn is not None:
#     373                 for hook in self._backward_hooks.values():
#     374                     wrapper = functools.partial(hook, self)
#     375                     functools.update_wrapper(wrapper, hook)
#     376                     grad_fn.register_hook(wrapper)
# --> 377         return result
#     378
# ipdb> n
# --Return--
# (Variable cont...size 19x1x50]
# , (Variable cont... size 1x1x50]
# , Variable cont... size 1x1x50]
# ))
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(377)__call__()
#     375                     functools.update_wrapper(wrapper, hook)
#     376                     grad_fn.register_hook(wrapper)
# --> 377         return result
#     378
#     379     def __setstate__(self, state):
#
# ipdb> n
# --Call--
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/warnings.py(468)__exit__()
#     466             return None
#     467
# --> 468     def __exit__(self, *exc_info):
#     469         if not self._entered:
#     470             raise RuntimeError("Cannot exit %r without entering first" % self)
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/warnings.py(469)__exit__()
#     467
#     468     def __exit__(self, *exc_info):
# --> 469         if not self._entered:
#     470             raise RuntimeError("Cannot exit %r without entering first" % self)
#     471         self._module.filters = self._filters
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/warnings.py(471)__exit__()
#     469         if not self._entered:
#     470             raise RuntimeError("Cannot exit %r without entering first" % self)
# --> 471         self._module.filters = self._filters
#     472         self._module._filters_mutated()
#     473         self._module.showwarning = self._showwarning
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/warnings.py(472)__exit__()
#     470             raise RuntimeError("Cannot exit %r without entering first" % self)
#     471         self._module.filters = self._filters
# --> 472         self._module._filters_mutated()
#     473         self._module.showwarning = self._showwarning
#     474         self._module._showwarnmsg_impl = self._showwarnmsg_impl
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/warnings.py(473)__exit__()
#     471         self._module.filters = self._filters
#     472         self._module._filters_mutated()
# --> 473         self._module.showwarning = self._showwarning
#     474         self._module._showwarnmsg_impl = self._showwarnmsg_impl
#     475
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/warnings.py(474)__exit__()
#     472         self._module._filters_mutated()
#     473         self._module.showwarning = self._showwarning
# --> 474         self._module._showwarnmsg_impl = self._showwarnmsg_impl
#     475
#     476
#
# ipdb> n
# --Return--
# None
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/warnings.py(474)__exit__()
#     472         self._module._filters_mutated()
#     473         self._module.showwarning = self._showwarning
# --> 474         self._module._showwarnmsg_impl = self._showwarnmsg_impl
#     475
#     476
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(96)forward()
#      94                 warnings.simplefilter("ignore")
#      95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
# ---> 96             new_hidden.append(new_h)
#      97             raw_outputs.append(raw_output)
#      98             if l != self.nlayers - 1: raw_output = drop(raw_output)
#
# ipdb> new_h.size()
# *** AttributeError: 'tuple' object has no attribute 'size'
# ipdb> len(new_h)
# 2
# ipdb> new_h[0].size()
# torch.Size([1, 1, 50])
# ipdb> new_h[1].size()
# torch.Size([1, 1, 50])
# ipdb> raw_output.size()
# torch.Size([19, 1, 50])
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(97)forward()
#      95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
#      96             new_hidden.append(new_h)
# ---> 97             raw_outputs.append(raw_output)
#      98             if l != self.nlayers - 1: raw_output = drop(raw_output)
#      99             outputs.append(raw_output)
# ipdb> len(new_hidden)
# 1
# ipdb> new_hidden
# [(Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 8
#    0.0442 -0.0321  0.0275  0.0765  0.0259 -0.0851  0.0561  0.0562 -0.0490
#
# Columns 9 to 17
#    0.0796  0.1238 -0.0084  0.0817  0.0627  0.0081  0.0837  0.0294 -0.0774
#
# Columns 18 to 26
#   -0.0091  0.1209 -0.1500  0.0010  0.0535  0.1974  0.0960 -0.0031  0.1180
#
# Columns 27 to 35
#   -0.0166  0.1620 -0.0534  0.0760 -0.0001  0.0030 -0.0915  0.1087  0.0415
#
# Columns 36 to 44
#    0.0417 -0.1289 -0.2170 -0.0240  0.0730 -0.0698 -0.1602 -0.1231 -0.0672
#
# Columns 45 to 49
#   -0.0341  0.1297 -0.0771 -0.0006 -0.0106
# [torch.FloatTensor of size 1x1x50]
# , Variable containing:
# (0 ,.,.) =
#
# Columns 0 to 8
#    0.0981 -0.1048  0.1103  0.1592  0.0981 -0.1869  0.0825  0.1477 -0.1041
#
# Columns 9 to 17
#    0.1242  0.3674 -0.0313  0.1732  0.1677  0.0232  0.2449  0.1831 -0.1468
#
# Columns 18 to 26
#   -0.0158  0.2473 -0.2689  0.0024  0.1316  0.4117  0.2161 -0.0075  0.2389
#
# Columns 27 to 35
#   -0.0482  0.2401 -0.1951  0.2428 -0.0002  0.0098 -0.1706  0.2301  0.1779
#
# Columns 36 to 44
#    0.0919 -0.3390 -0.3941 -0.0918  0.1917 -0.2564 -0.3814 -0.2366 -0.2095
#
# Columns 45 to 49
#   -0.1163  0.2835 -0.2112 -0.0014 -0.0197
# [torch.FloatTensor of size 1x1x50]
# )]
# ipdb> new_hidden.size()
# *** AttributeError: 'list' object has no attribute 'size'
# ipdb> new_hidden[0].size()
# *** AttributeError: 'tuple' object has no attribute 'size'
# ipdb> ll
#      72     def forward(self, input):
#      73         """ Invoked during the forward propagation of the RNN_Encoder module.
#      74         Args:
#      75             input (Tensor): input of shape (batch_size x sentence length)
#      76
#      77         Returns:
#      78             raw_outputs (tuple(list (Tensor), list(Tensor)): list of tensors evaluated from each RNN layer without using
#      79             dropouth, list of tensors evaluated from each RNN layer using dropouth,
#      80         """
#      81         sl,bs = input.size()
#      82         if bs!=self.bs:
#      83             self.bs=bs
#      84             self.reset()
#      85
#      86         emb = self.encoder_with_dropout(input, dropout=self.dropoute if self.training else 0)
#      87         emb = self.dropouti(emb)
#      88
#      89         raw_output = emb
#      90         new_hidden,raw_outputs,outputs = [],[],[]
#      91         for l, (rnn,drop) in enumerate(zip(self.rnns, self.dropouths)):
#      92             current_input = raw_output
#      93             with warnings.catch_warnings():
#      94                 warnings.simplefilter("ignore")
#      95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
#      96             new_hidden.append(new_h)
# ---> 97             raw_outputs.append(raw_output)
#      98             if l != self.nlayers - 1: raw_output = drop(raw_output)
#      99             outputs.append(raw_output)
#     100
#     101         self.hidden = repackage_var(new_hidden)
#     102         return raw_outputs, outputs
#     103
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(98)forward()
#      96             new_hidden.append(new_h)
#      97             raw_outputs.append(raw_output)
# ---> 98             if l != self.nlayers - 1: raw_output = drop(raw_output)
#      99             outputs.append(raw_output)
#     100
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(99)forward()
#      97             raw_outputs.append(raw_output)
#      98             if l != self.nlayers - 1: raw_output = drop(raw_output)
# ---> 99             outputs.append(raw_output)
#     100
#     101         self.hidden = repackage_var(new_hidden)
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(91)forward()
#      89         raw_output = emb
#      90         new_hidden,raw_outputs,outputs = [],[],[]
# ---> 91         for l, (rnn,drop) in enumerate(zip(self.rnns, self.dropouths)):
#      92             current_input = raw_output
#      93             with warnings.catch_warnings():
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(92)forward()
#      90         new_hidden,raw_outputs,outputs = [],[],[]
#      91         for l, (rnn,drop) in enumerate(zip(self.rnns, self.dropouths)):
# ---> 92             current_input = raw_output
#      93             with warnings.catch_warnings():
#      94                 warnings.simplefilter("ignore")
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(93)forward()
#      91         for l, (rnn,drop) in enumerate(zip(self.rnns, self.dropouths)):
#      92             current_input = raw_output
# ---> 93             with warnings.catch_warnings():
#      94                 warnings.simplefilter("ignore")
#      95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(94)forward()
#      92             current_input = raw_output
#      93             with warnings.catch_warnings():
# ---> 94                 warnings.simplefilter("ignore")
#      95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
#      96             new_hidden.append(new_h)
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(95)forward()
#      93             with warnings.catch_warnings():
#      94                 warnings.simplefilter("ignore")
# ---> 95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
#      96             new_hidden.append(new_h)
#      97             raw_outputs.append(raw_output)
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(96)forward()
#      94                 warnings.simplefilter("ignore")
#      95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
# ---> 96             new_hidden.append(new_h)
#      97             raw_outputs.append(raw_output)
#      98             if l != self.nlayers - 1: raw_output = drop(raw_output)
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(97)forward()
#      95                 raw_output, new_h = rnn(raw_output, self.hidden[l])
#      96             new_hidden.append(new_h)
# ---> 97             raw_outputs.append(raw_output)
#      98             if l != self.nlayers - 1: raw_output = drop(raw_output)
#      99             outputs.append(raw_output)
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(98)forward()
#      96             new_hidden.append(new_h)
#      97             raw_outputs.append(raw_output)
# ---> 98             if l != self.nlayers - 1: raw_output = drop(raw_output)
#      99             outputs.append(raw_output)
#     100
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(99)forward()
#      97             raw_outputs.append(raw_output)
#      98             if l != self.nlayers - 1: raw_output = drop(raw_output)
# ---> 99             outputs.append(raw_output)
#     100
#     101         self.hidden = repackage_var(new_hidden)
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(91)forward()
#      89         raw_output = emb
#      90         new_hidden,raw_outputs,outputs = [],[],[]
# ---> 91         for l, (rnn,drop) in enumerate(zip(self.rnns, self.dropouths)):
#      92             current_input = raw_output
#      93             with warnings.catch_warnings():
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(101)forward()
#      99             outputs.append(raw_output)
#     100
# --> 101         self.hidden = repackage_var(new_hidden)
#     102         return raw_outputs, outputs
#     103
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(102)forward()
#     100
#     101         self.hidden = repackage_var(new_hidden)
# --> 102         return raw_outputs, outputs
#     103
#     104     def one_hidden(self, l):
#
# ipdb> raw_outputs.size()
# *** AttributeError: 'list' object has no attribute 'size'
# ipdb> len(raw_outputs)
# 2
# ipdb> n
# --Return--
# ([Variable cont...size 19x1x50]
# , Variable cont...size 19x1x20]
# ], [Variable cont...size 19x1x50]
# , Variable cont...size 19x1x20]
# ])
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(102)forward()
#     100
#     101         self.hidden = repackage_var(new_hidden)
# --> 102         return raw_outputs, outputs
#     103
#     104     def one_hidden(self, l):
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(358)__call__()
#     356         else:
#     357             result = self.forward(*input, **kwargs)
# --> 358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#     360             if hook_result is not None:
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(364)__call__()
#     362                     "forward hooks should never return any values, but '{}'"
#     363                     "didn't return None".format(hook))
# --> 364         if len(self._backward_hooks) > 0:
#     365             var = result
#     366             while not isinstance(var, Variable):
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(377)__call__()
#     375                     functools.update_wrapper(wrapper, hook)
#     376                     grad_fn.register_hook(wrapper)
# --> 377         return result
#     378
#     379     def __setstate__(self, state):
#
# ipdb> n
# --Return--
# ([Variable cont...size 19x1x50]
# , Variable cont...size 19x1x20]
# ], [Variable cont...size 19x1x50]
# , Variable cont...size 19x1x20]
# ])
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(377)__call__()
#     375                     functools.update_wrapper(wrapper, hook)
#     376                     grad_fn.register_hook(wrapper)
# --> 377         return result
#     378
#     379     def __setstate__(self, state):
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/container.py(66)forward()
#      64
#      65     def forward(self, input):
# ---> 66         for module in self._modules.values():
#      67             input = module(input)
#      68         return input
#
# ipdb> ll
#      65     def forward(self, input):
# ---> 66         for module in self._modules.values():
#      67             input = module(input)
#      68         return input
#      69
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/container.py(67)forward()
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ipdb> s
# --Call--
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(351)__call__()
#     349         return result
#     350
# --> 351     def __call__(self, *input, **kwargs):
#     352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(352)__call__()
#     350
#     351     def __call__(self, *input, **kwargs):
# --> 352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
#     354         if torch.jit._tracing:
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(354)__call__()
#     352         for hook in self._forward_pre_hooks.values():
#     353             hook(self, input)
# --> 354         if torch.jit._tracing:
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(357)__call__()
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ipdb> s
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(142)forward()
#     140         if tie_encoder: self.decoder.weight = tie_encoder.weight
#     141
# --> 142     def forward(self, input):
#     143         raw_outputs, outputs = input
#     144         output = self.dropout(outputs[-1])
#
# ipdb> ll
# --> 142     def forward(self, input):
#     143         raw_outputs, outputs = input
#     144         output = self.dropout(outputs[-1])
#     145         decoded = self.decoder(output.view(output.size(0)*output.size(1), output.size(2)))
#     146         result = decoded.view(-1, decoded.size(1))
#     147         return result, raw_outputs, outputs
#     148
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(143)forward()
#     141
#     142     def forward(self, input):
# --> 143         raw_outputs, outputs = input
#     144         output = self.dropout(outputs[-1])
#     145         decoded = self.decoder(output.view(output.size(0)*output.size(1), output.size(2)))
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(144)forward()
#     142     def forward(self, input):
#     143         raw_outputs, outputs = input
# --> 144         output = self.dropout(outputs[-1])
#     145         decoded = self.decoder(output.view(output.size(0)*output.size(1), output.size(2)))
#     146         result = decoded.view(-1, decoded.size(1))
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(145)forward()
#     143         raw_outputs, outputs = input
#     144         output = self.dropout(outputs[-1])
# --> 145         decoded = self.decoder(output.view(output.size(0)*output.size(1), output.size(2)))
#     146         result = decoded.view(-1, decoded.size(1))
#     147         return result, raw_outputs, outputs
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(146)forward()
#     144         output = self.dropout(outputs[-1])
#     145         decoded = self.decoder(output.view(output.size(0)*output.size(1), output.size(2)))
# --> 146         result = decoded.view(-1, decoded.size(1))
#     147         return result, raw_outputs, outputs
#     148
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(147)forward()
#     145         decoded = self.decoder(output.view(output.size(0)*output.size(1), output.size(2)))
#     146         result = decoded.view(-1, decoded.size(1))
# --> 147         return result, raw_outputs, outputs
#     148
#     149
#
# ipdb> n
# --Return--
# (Variable cont...size 19x1141]
# , [Variable cont...size 19x1x50]
# , Variable cont...size 19x1x20]
# ], [Variable cont...size 19x1x50]
# , Variable cont...size 19x1x20]
# ])
# > /home/zero/fastai/courses/dl1/fastai/lm_rnn.py(147)forward()
#     145         decoded = self.decoder(output.view(output.size(0)*output.size(1), output.size(2)))
#     146         result = decoded.view(-1, decoded.size(1))
# --> 147         return result, raw_outputs, outputs
#     148
#     149
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(358)__call__()
#     356         else:
#     357             result = self.forward(*input, **kwargs)
# --> 358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#     360             if hook_result is not None:
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(364)__call__()
#     362                     "forward hooks should never return any values, but '{}'"
#     363                     "didn't return None".format(hook))
# --> 364         if len(self._backward_hooks) > 0:
#     365             var = result
#     366             while not isinstance(var, Variable):
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(377)__call__()
#     375                     functools.update_wrapper(wrapper, hook)
#     376                     grad_fn.register_hook(wrapper)
# --> 377         return result
#     378
#     379     def __setstate__(self, state):
#
# ipdb> n
# --Return--
# (Variable cont...size 19x1141]
# , [Variable cont...size 19x1x50]
# , Variable cont...size 19x1x20]
# ], [Variable cont...size 19x1x50]
# , Variable cont...size 19x1x20]
# ])
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(377)__call__()
#     375                     functools.update_wrapper(wrapper, hook)
#     376                     grad_fn.register_hook(wrapper)
# --> 377         return result
#     378
#     379     def __setstate__(self, state):
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/container.py(66)forward()
#      64
#      65     def forward(self, input):
# ---> 66         for module in self._modules.values():
#      67             input = module(input)
#      68         return input
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/container.py(68)forward()
#      66         for module in self._modules.values():
#      67             input = module(input)
# ---> 68         return input
#      69
#      70
# ipdb> input.size()
# *** AttributeError: 'tuple' object has no attribute 'size'
# ipdb> input[0].size()
# torch.Size([19, 1141])
# ipdb> n
# --Return--
# (Variable cont...size 19x1141]
# , [Variable cont...size 19x1x50]
# , Variable cont...size 19x1x20]
# ], [Variable cont...size 19x1x50]
# , Variable cont...size 19x1x20]
# ])
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/container.py(68)forward()
#      66         for module in self._modules.values():
#      67             input = module(input)
# ---> 68         return input
#      69
#      70
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(358)__call__()
#     356         else:
#     357             result = self.forward(*input, **kwargs)
# --> 358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#     360             if hook_result is not None:
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(364)__call__()
#     362                     "forward hooks should never return any values, but '{}'"
#     363                     "didn't return None".format(hook))
# --> 364         if len(self._backward_hooks) > 0:
#     365             var = result
#     366             while not isinstance(var, Variable):
#
# ipdb> n
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(377)__call__()
#     375                     functools.update_wrapper(wrapper, hook)
#     376                     grad_fn.register_hook(wrapper)
# --> 377         return result
#     378
#     379     def __setstate__(self, state):
#
# ipdb> n
# --Return--
# (Variable cont...size 19x1141]
# , [Variable cont...size 19x1x50]
# , Variable cont...size 19x1x20]
# ], [Variable cont...size 19x1x50]
# , Variable cont...size 19x1x20]
# ])
# > /home/zero/anaconda/envs/fastai-cpu/lib/python3.6/site-packages/torch/nn/modules/module.py(377)__call__()
#     375                     functools.update_wrapper(wrapper, hook)
#     376                     grad_fn.register_hook(wrapper)
# --> 377         return result
#     378
#     379     def __setstate__(self, state):
#
# ipdb> n
# --Return--
# None
# > <string>(1)<module>()
#
# ipdb> n

# %%
ss = "món ăn rất ngon"
t = TEXT.numericalize([spacy_tok(ss)])

# %%
print(ss,"\n")
# Get predictions from model
res,*_ = m(t)

for i in range(50):
    n=res[-1].topk(2)[1] #select top 2 id of prediction
    n = n[1] if n.data[0]==0 else n[0] #if is unknow then choose the second
    print(TEXT.vocab.itos[n.data[0]], end=' ')
    t = torch.cat((t[-9:], n[0].unsqueeze(0)), 0)
    res,*_ = m(t)
print('...')
# Out:
# món ăn rất ngon
#
# thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , thơm , ...

# %%
print(ss,"\n")
res,*_ = m(t)

for i in range(50):
    n=res[-1].topk(2)[1] #select top 2 id of prediction
    n = n[1] if n.data[0]==0 else n[0] #if is unknow then choose the second
    print(TEXT.vocab.itos[n.data[0]], end=' ')
    
    res,*_ = m(n[0].unsqueeze(0))
print('...')
# Out:
# nhất
#
# , không gian rộng rãi , thoáng mát , không gian khá thoáng , không gian rộng rãi , thoáng mát , không gian khá thoáng , không gian rộng rãi , thoáng mát , không gian khá thoáng , không gian rộng rãi , thoáng mát , không gian ...

# %% [markdown]
# ### Sentiment

# %% [markdown]
# We'll need to the saved vocab from the language model, since we need to ensure the same words map to the same IDs.

# %%
TEXT = pickle.load(open(f'{PATH}models/TEXT.pkl','rb'))

# %% [markdown]
# `sequential=False` tells torchtext that a text field should be tokenized (in this case, we just want to store the 'positive' or 'negative' single label).
#
# `splits` is a torchtext method that creates train, test, and validation sets. The IMDB dataset is built into torchtext, so we can take advantage of that. Take a look at `lang_model-arxiv.ipynb` to see how to define your own fastai/torchtext datasets.

# %%
reviews_label = reviews_label[['review_content', 'score']]

# %%
reviews_label.columns = ['text', 'label']

# %%
reviews_label['label'] = reviews_label['label'].apply(lambda t: 'pos' if t > 5 else 'neg')

# %%
class foody_dataset(torchtext.data.Dataset):
    def __init__(self, df, text_field, label_field, **kwargs):
        fields = [('text', text_field), ('label', label_field)]
        examples = []
        for label in ['pos', 'neg']:
            for text in df[df['label'] == label]['text'].values:
                examples.append(data.Example.fromlist([text, label], fields))
        super().__init__(examples, fields, **kwargs)

    @staticmethod
    def sort_key(ex): return len(ex.text)
    
    @classmethod
    def splits(cls, text_field, label_field, train_data='train', val_data = 'val', test_data=None):
        return tuple(cls(d, text_field = text_field, label_field = label_field) 
                     for d in (train_data, val_data, test_data) if d is not None)

# %%
foody_label = data.Field(sequential=False)

# %%
splits = foody_dataset.splits(text_field = TEXT, label_field = foody_label, 
                              train_data = reviews_label[:1000], val_data = reviews_label[:1000])

# %%
t = splits[0].examples[0]
t.label, ' '.join(t.text[:16])
# Out:
# ('pos', 'quán steak hiếm hoi mà mình cực kì ưng ý từ lâu nay khi quán bên')

# %% [markdown]
# fastai can create a ModelData object directly from torchtext splits.

# %%
md2 = TextData.from_splits(PATH, splits, bs)

# %%
m3 = md2.get_model(opt_fn, 1500, bptt, emb_sz=em_sz, n_hid=nh, n_layers=nl, 
           dropout=0.1, dropouti=0.4, wdrop=0.5, dropoute=0.05, dropouth=0.3)
m3.reg_fn = partial(seq2seq_reg, alpha=2, beta=1)
m3.load_encoder(f'adam1_enc')

# %% [markdown]
# Because we're fine-tuning a pretrained model, we'll use differential learning rates, and also increase the max gradient for clipping, to allow the SGDR to work better.

# %%
m3.fit(lrs/2, 1, metrics=[accuracy])
# Out:
# NOTE: Enter 'c' at the ipdb>  prompt to continue execution.
# None
# > <string>(1)<module>()
#
# ipdb> s
# None
# > <string>(2)<module>()
#
# ipdb> s
# None
# > <string>(3)<module>()
#
# ipdb> s
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/learner.py(188)fit()
#     186         return LayerOptimizer(self.opt_fn, self.get_layer_groups(), lrs, wds)
#     187
# --> 188     def fit(self, lrs, n_cycle, wds=None, **kwargs):
#     189
#     190         """Method gets an instance of LayerOptimizer and delegates to self.fit_gen(..)
#
# ipdb> s
# > /home/zero/fastai/courses/dl1/fastai/learner.py(213)fit()
#     211             None
#     212         """
# --> 213         self.sched = None
#     214         layer_opt = self.get_layer_opt(lrs, wds)
#     215         return self.fit_gen(self.model, self.data, layer_opt, n_cycle, **kwargs)
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/learner.py(214)fit()
#     212         """
#     213         self.sched = None
# --> 214         layer_opt = self.get_layer_opt(lrs, wds)
#     215         return self.fit_gen(self.model, self.data, layer_opt, n_cycle, **kwargs)
#     216
#
# ipdb> n
# > /home/zero/fastai/courses/dl1/fastai/learner.py(215)fit()
#     213         self.sched = None
#     214         layer_opt = self.get_layer_opt(lrs, wds)
# --> 215         return self.fit_gen(self.model, self.data, layer_opt, n_cycle, **kwargs)
#     216
#     217     def warm_up(self, lr, wds=None):
#
# ipdb> s
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/learner.py(39)model()
#      37     def children(self): return children(self.model)
#      38
# ---> 39     @property
#      40     def model(self): return self.models.model
#      41
#
# ipdb> ll
# ---> 39     @property
#      40     def model(self): return self.models.model
#      41
#
# ipdb> s
# > /home/zero/fastai/courses/dl1/fastai/learner.py(40)model()
#      38
#      39     @property
# ---> 40     def model(self): return self.models.model
#      41
#      42     @property
#
# ipdb> s
# --Return--
# SequentialRNN... )
#     )
#   )
# )
# > /home/zero/fastai/courses/dl1/fastai/learner.py(40)model()
#      38
#      39     @property
# ---> 40     def model(self): return self.models.model
#      41
#      42     @property
#
# ipdb> s
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/learner.py(42)data()
#      40     def model(self): return self.models.model
#      41
# ---> 42     @property
#      43     def data(self): return self.data_
#      44
#
# ipdb> s
# > /home/zero/fastai/courses/dl1/fastai/learner.py(43)data()
#      41
#      42     @property
# ---> 43     def data(self): return self.data_
#      44
#      45     def summary(self): return model_summary(self.model, [3,self.data.sz,self.data.sz])
#
# ipdb> ll
#      42     @property
# ---> 43     def data(self): return self.data_
#      44
#
# ipdb> s
# --Return--
# <fastai.nlp.T...x7f726282f710>
# > /home/zero/fastai/courses/dl1/fastai/learner.py(43)data()
#      41
#      42     @property
# ---> 43     def data(self): return self.data_
#      44
#      45     def summary(self): return model_summary(self.model, [3,self.data.sz,self.data.sz])
# ipdb> s
# --Call--
# > /home/zero/fastai/courses/dl1/fastai/learner.py(75)fit_gen()
#      73     def load_cycle(self, name, cycle): self.load(f'{name}_cyc_{cycle}')
#      74
# ---> 75     def fit_gen(self, model, data, layer_opt, n_cycle, cycle_len=None, cycle_mult=1, cycle_save_name=None, best_save_name=None,
#      76                 use_clr=None, metrics=None, callbacks=None, use_wd_sched=False, norm_wds=False, wds_sched_mult=None, **kwargs):
#      77
#
# ipdb> ll
# ---> 75     def fit_gen(self, model, data, layer_opt, n_cycle, cycle_len=None, cycle_mult=1, cycle_save_name=None, best_save_name=None,
#      76                 use_clr=None, metrics=None, callbacks=None, use_wd_sched=False, norm_wds=False, wds_sched_mult=None, **kwargs):
#      77
#      78         """Method does some preparation before finally delegating to the 'fit' method for
#      79         fitting the model. Namely, if cycle_len is defined, it adds a 'Cosine Annealing'
#      80         scheduler for varying the learning rate across iterations.
#      81
#      82         Method also computes the total number of epochs to fit based on provided 'cycle_len',
#      83         'cycle_mult', and 'n_cycle' parameters.
#      84
#      85         Args:
#      86             model (Learner):  Any neural architecture for solving a supported problem.
#      87                 Eg. ResNet-34, RNN_Learner etc.
#      88
#      89             data (ModelData): An instance of ModelData.
#      90
#      91             layer_opt (LayerOptimizer): An instance of the LayerOptimizer class
#      92
#      93             n_cycle (int): number of cycles
#      94
#      95             cycle_len (int):  number of cycles before lr is reset to the initial value.
#      96                 E.g if cycle_len = 3, then the lr is varied between a maximum
#      97                 and minimum value over 3 epochs.
#      98
#      99             cycle_mult (int): additional parameter for influencing how the lr resets over
#     100                 the cycles. For an intuitive explanation, please see
#     101                 https://github.com/fastai/fastai/blob/master/courses/dl1/lesson1.ipynb
#     102
#     103             cycle_save_name (str): use to save the weights at end of each cycle
#     104
#     105             best_save_name (str): use to save weights of best model during training.
#     106
#     107             metrics (function): some function for evaluating a desired metric. Eg. accuracy.
#     108
#     109             callbacks (list(Callback)): callbacks to apply during the training.
#     110
#     111             use_wd_sched (bool, optional): set to True to enable weight regularization using
#     112                 the technique mentioned in https://arxiv.org/abs/1711.05101. When this is True
#     113                 alone (see below), the regularization is detached from gradient update and
#     114                 applied directly to the weights.
#     115
#     116             norm_wds (bool, optional): when this is set to True along with use_wd_sched, the
#     117                 regularization factor is normalized with each training cycle.
#     118
#     119             wds_sched_mult (function, optional): when this is provided along with use_wd_sched
#     120                 as True, the value computed by this function is multiplied with the regularization
#     121                 strength. This function is passed the WeightDecaySchedule object. And example
#     122                 function that can be passed is:
#     123                             f = lambda x: np.array(x.layer_opt.lrs) / x.init_lrs
#     124
#     125             kwargs: other optional arguments
#     126
#     127         Returns:
#     128             None
#     129         """
#     130
#     131         if callbacks is None: callbacks=[]
#     132         if metrics is None: metrics=self.metrics
#     133
#     134         if use_wd_sched:
#     135             # This needs to come before CosAnneal() because we need to read the initial learning rate from
#     136             # layer_opt.lrs - but CosAnneal() alters the layer_opt.lrs value initially (divides by 100)
#     137             if np.sum(layer_opt.wds) == 0:
#     138                 print('fit() warning: use_wd_sched is set to True, but weight decay(s) passed are 0. Use wds to '
#     139                       'pass weight decay values.')
#     140             batch_per_epoch = len(data.trn_dl)
#     141             cl = cycle_len if cycle_len else 1
#     142             self.wd_sched = WeightDecaySchedule(layer_opt, batch_per_epoch, cl, cycle_mult, n_cycle,
#     143                                                 norm_wds, wds_sched_mult)
#     144             callbacks += [self.wd_sched]
#     145
#     146         elif use_clr is not None:
#     147             clr_div,cut_div = use_clr
#     148             cycle_end = self.get_cycle_end(cycle_save_name)
#     149             self.sched = CircularLR(layer_opt, len(data.trn_dl)*cycle_len, on_cycle_end=cycle_end, div=clr_div, cut_div=cut_div)
#     150         elif cycle_len:
#     151             cycle_end = self.get_cycle_end(cycle_save_name)
#     152             cycle_batches = len(data.trn_dl)*cycle_len
#     153             self.sched = CosAnneal(layer_opt, cycle_batches, on_cycle_end=cycle_end, cycle_mult=cycle_mult)
#     154         elif not self.sched: self.sched=LossRecorder(layer_opt)
#     155         callbacks+=[self.sched]
#     156
#     157         if best_save_name is not None:
#     158             callbacks+=[SaveBestModel(self, layer_opt, best_save_name)]
#     159
#     160         n_epoch = sum_geom(cycle_len if cycle_len else 1, cycle_mult, n_cycle)
#     161         return fit(model, data, n_epoch, layer_opt.opt, self.crit,
#     162             metrics=metrics, callbacks=callbacks, reg_fn=self.reg_fn, clip=self.clip, **kwargs)
#     163
# ipdb> c
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      1.076536   1.162651   0.004102

# %%
##########################

# %%
m3.fit(lrs/2, 1, metrics=[accuracy])
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      1.089313   1.125159   0.086133
# [1.1251591, 0.0861328125]

# %%
m3.clip=25.
lrs=np.array([1e-4,1e-3,1e-2])

# %%
m3.freeze_to(-1)
m3.fit(lrs/2, 1, metrics=[accuracy])
m3.unfreeze()
m3.fit(lrs, 1, metrics=[accuracy], cycle_len=1)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      1.073348   1.236768   0.0
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      1.081271   1.187813   0.0
# [1.187813, 0.0]

# %%
m3.fit(lrs, 1, metrics=[accuracy], cycle_len=2, cycle_save_name='imdb2')
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=2), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      1.075842   1.081935   0.523438
#     1      1.073571   1.151045   0.070508
# [1.1510453, 0.0705078125]

# %%
m3.predict_array()

# %%
m3.load_cycle('imdb2', 4)

# %%
accuracy_np(*m3.predict_with_targs())
# Out:
# 0.94310897435897434

# %% [markdown]
# A recent paper from Bradbury et al, [Learned in translation: contextualized word vectors](https://einstein.ai/research/learned-in-translation-contextualized-word-vectors), has a handy summary of the latest academic research in solving this IMDB sentiment analysis problem. Many of the latest algorithms shown are tuned for this specific problem.
#
# ![image.png](attachment:image.png)
#
# As you see, we just got a new state of the art result in sentiment analysis, decreasing the error from 5.9% to 5.5%! You should be able to get similarly world-class results on other NLP classification problems using the same basic steps.
#
# There are many opportunities to further improve this, although we won't be able to get to them until part 2 of this course...

# %% [markdown]
# ### End
